# %%
#Import Dependencies
import os
import glob
import pandas as pd
os.chdir("/Users/Dylan2/Desktop/18-Tableau/Resources")

# %%
#Use glob to match the pattern 'csv' and save the list of file names in the 'all_filenames' variable
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "2020_csv.csv", index=False, encoding='utf-8-sig')

# %%
year2020_df = pd.read_csv("2020_csv.csv")
year2020_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1           242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2           124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3           104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4           228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3185          City Hall               40.717732
# 2              3272       Jersey & 3rd               40.723332
# 3              3202       Newport PATH               40.727224
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id   end station name  \
# 0               -74.033759            3203      Hamilton Park
# ...

# %%
year2020_df.info
# Out:
# <bound method DataFrame.info of         tripduration                 starttime                  stoptime  \
# 0                389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1                242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2                124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3                104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4                228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
# ...              ...                       ...                       ...
# 344831           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 344832           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 344833           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 344834           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 344835           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
# ...
